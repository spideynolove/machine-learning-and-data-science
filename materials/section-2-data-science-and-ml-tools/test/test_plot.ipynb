# %%
import pandas as pd

# %%
# Import matplotlib and setup the figures to display within the notebook
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])

# %%
dxym = pd.read_csv('../../data/currencies/download/Dxy_MONTH_DL.csv', index_col='Date', parse_dates=True)
dxym.drop(columns=['Vol.'], inplace=True)
dxym
# Out:
#              Price    Open    High     Low Change %
# Date
# 2024-04-01  106.09  104.49  106.52  103.88    1.54%
# 2024-03-01  104.49  104.13  104.73  102.36    0.32%
# 2024-02-01  104.16  103.51  104.98  102.90    0.85%
# 2024-01-01  103.27  101.42  103.82  101.34    1.92%
# 2023-12-01  101.33  103.36  104.26  100.62   -2.09%
# ...            ...     ...     ...     ...      ...
# 2007-05-01   82.30   81.42   82.60   81.25    1.04%
# 2007-04-01   81.45   82.91   83.21   81.27   -1.78%
# 2007-03-01   82.93   83.62   84.38   82.64   -0.77%
# 2007-02-01   83.57   84.65   85.21   83.40   -1.23%
# 2007-01-01   84.61   83.46   85.43   83.15    1.06%
#
# [208 rows x 5 columns]

# %%
plt.plot(dxym['Price'])
