# %%
import pandas as pd

# %%
# 2 main datatypes
series = pd.Series(["BMW", "Toyota", "Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
# series = 1-dimensional

# %%
colours = pd.Series(["Red", "Blue", "White"])
colours
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
# DataFrame = 2-dimensional
car_data = pd.DataFrame({"Car make": series, "Colour": colours})
car_data
# Out:
#   Car make Colour
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  White

# %%
# Import data
# car_sales = pd.read_csv("../data/car-sales.csv")
car_sales = pd.read_csv("../data/car-sales-faker.csv")

# %%
car_sales
# Out:
#            Make   Colour  Odometer (KM)  Doors    Price
# 0           Ram  fuchsia          13295      2  $40,681
# 1     Chevrolet     navy          47817      7  $27,367
# 2      INFINITI     gray          94484      5  $15,164
# 3     Chevrolet   yellow          82774      7  $31,538
# 4        Nissan    olive           9845      3  $90,121
# ...         ...      ...            ...    ...      ...
# 4995        GMC     gray          66301      4  $96,958
# 4996   Chrysler  fuchsia          15145      5  $77,949
# 4997   Cadillac     teal          54776      6  $15,387
# 4998      Lexus     aqua          72956      4  $88,575
# 4999      Lotus     aqua          93944      2  $99,848
#
# [5000 rows x 5 columns]

# %%
# Exporting a dataframe
# car_sales.to_csv("exported-car-sales.csv", index=False)
car_sales.to_csv("exported-car-sales-faker.csv", index=False)

# %%
# exported_car_sales = pd.read_csv("exported-car-sales.csv")
exported_car_sales = pd.read_csv("exported-car-sales-faker.csv")
exported_car_sales
# Out:
#            Make   Colour  Odometer (KM)  Doors    Price
# 0           Ram  fuchsia          13295      2  $40,681
# 1     Chevrolet     navy          47817      7  $27,367
# 2      INFINITI     gray          94484      5  $15,164
# 3     Chevrolet   yellow          82774      7  $31,538
# 4        Nissan    olive           9845      3  $90,121
# ...         ...      ...            ...    ...      ...
# 4995        GMC     gray          66301      4  $96,958
# 4996   Chrysler  fuchsia          15145      5  $77,949
# 4997   Cadillac     teal          54776      6  $15,387
# 4998      Lexus     aqua          72956      4  $88,575
# 4999      Lotus     aqua          93944      2  $99,848
#
# [5000 rows x 5 columns]

# %% [markdown]
# ### using first 100 samples of the data

# %%
car_sales = car_sales.tail(100)
car_sales.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## Describe data

# %%
# Attribute
car_sales.dtypes

# Function
#car_sales.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
car_sales
# Out:
#         Make   Colour  Odometer (KM)  Doors    Price
# 0      MAZDA  fuchsia          79473      4  $50,116
# 1     Toyota     gray          51047      7  $40,832
# 2   INFINITI     blue          41587      7  $58,986
# 3       Ford     gray          41958      5  $67,301
# 4        GMC   yellow          75973      6  $59,806
# ..       ...      ...            ...    ...      ...
# 95       GMC     gray          66301      4  $96,958
# 96  Chrysler  fuchsia          15145      5  $77,949
# 97  Cadillac     teal          54776      6  $15,387
# 98     Lexus     aqua          72956      4  $88,575
# 99     Lotus     aqua          93944      2  $99,848
#
# [100 rows x 5 columns]

# %%
car_sales.describe()
# Out:
#        Odometer (KM)       Doors
# count     100.000000  100.000000
# mean    51573.320000    4.340000
# std     27072.925781    1.677059
# min      1257.000000    2.000000
# 25%     31865.000000    3.000000
# 50%     51605.500000    4.000000
# 75%     72860.000000    6.000000
# max     99613.000000    7.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           100 non-null    object
#  1   Colour         100 non-null    object
#  2   Odometer (KM)  100 non-null    int64
#  3   Doors          100 non-null    int64
#  4   Price          100 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 4.0+ KB

# %%
car_sales
# Out:
#         Make   Colour  Odometer (KM)  Doors    Price
# 0      MAZDA  fuchsia          79473      4  $50,116
# 1     Toyota     gray          51047      7  $40,832
# 2   INFINITI     blue          41587      7  $58,986
# 3       Ford     gray          41958      5  $67,301
# 4        GMC   yellow          75973      6  $59,806
# ..       ...      ...            ...    ...      ...
# 95       GMC     gray          66301      4  $96,958
# 96  Chrysler  fuchsia          15145      5  $77,949
# 97  Cadillac     teal          54776      6  $15,387
# 98     Lexus     aqua          72956      4  $88,575
# 99     Lotus     aqua          93944      2  $99,848
#
# [100 rows x 5 columns]

# %%
# car_sales.mean()    # error

# %%
car_prices = pd.Series([3000, 1500, 111250])
car_prices.mean()
# Out:
# 38583.333333333336

# %%
car_sales.sum()
# Out:
# Make             MAZDAToyotaINFINITIFordGMCJaguarDodgeLand Rove...
# Colour           fuchsiagraybluegrayyellowaquagraybluepurpleaqu...
# Odometer (KM)                                              5157332
# Doors                                                          434
# Price            $50,116$40,832$58,986$67,301$59,806$59,649$72,...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# 434

# %%
len(car_sales)
# Out:
# 100

# %%
car_sales
# Out:
#         Make   Colour  Odometer (KM)  Doors    Price
# 0      MAZDA  fuchsia          79473      4  $50,116
# 1     Toyota     gray          51047      7  $40,832
# 2   INFINITI     blue          41587      7  $58,986
# 3       Ford     gray          41958      5  $67,301
# 4        GMC   yellow          75973      6  $59,806
# ..       ...      ...            ...    ...      ...
# 95       GMC     gray          66301      4  $96,958
# 96  Chrysler  fuchsia          15145      5  $77,949
# 97  Cadillac     teal          54776      6  $15,387
# 98     Lexus     aqua          72956      4  $88,575
# 99     Lotus     aqua          93944      2  $99,848
#
# [100 rows x 5 columns]

# %% [markdown]
# ## Viewing and selecting data

# %%
car_sales.head()
# Out:
#        Make   Colour  Odometer (KM)  Doors    Price
# 0     MAZDA  fuchsia          79473      4  $50,116
# 1    Toyota     gray          51047      7  $40,832
# 2  INFINITI     blue          41587      7  $58,986
# 3      Ford     gray          41958      5  $67,301
# 4       GMC   yellow          75973      6  $59,806

# %%
car_sales
# Out:
#         Make   Colour  Odometer (KM)  Doors    Price
# 0      MAZDA  fuchsia          79473      4  $50,116
# 1     Toyota     gray          51047      7  $40,832
# 2   INFINITI     blue          41587      7  $58,986
# 3       Ford     gray          41958      5  $67,301
# 4        GMC   yellow          75973      6  $59,806
# ..       ...      ...            ...    ...      ...
# 95       GMC     gray          66301      4  $96,958
# 96  Chrysler  fuchsia          15145      5  $77,949
# 97  Cadillac     teal          54776      6  $15,387
# 98     Lexus     aqua          72956      4  $88,575
# 99     Lotus     aqua          93944      2  $99,848
#
# [100 rows x 5 columns]

# %%
car_sales.head(7)
# Out:
#        Make   Colour  Odometer (KM)  Doors    Price
# 0     MAZDA  fuchsia          79473      4  $50,116
# 1    Toyota     gray          51047      7  $40,832
# 2  INFINITI     blue          41587      7  $58,986
# 3      Ford     gray          41958      5  $67,301
# 4       GMC   yellow          75973      6  $59,806
# 5    Jaguar     aqua          83830      2  $59,649
# 6     Dodge     gray           8541      5  $72,562

# %%
car_sales.tail(3)
# Out:
#         Make Colour  Odometer (KM)  Doors    Price
# 97  Cadillac   teal          54776      6  $15,387
# 98     Lexus   aqua          72956      4  $88,575
# 99     Lotus   aqua          93944      2  $99,848

# %%
# .loc & .iloc
animals = pd.Series(["cat", "dog", "bird", "panda", "snake"],
                    index=[0, 3, 9, 8, 3])

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.loc[9]
# Out:
# 'bird'

# %%
car_sales.loc[3]
# Out:
# Make              ford
# Colour            gray
# Odometer (KM)    41958
# Doors                5
# Price            67301
# Seats              5.0
# Name: 3, dtype: object

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
# .iloc refers to position
animals.iloc[3]
# Out:
# 'panda'

# %%
# .loc refers to index
car_sales.loc[3]
# Out:
# Make              ford
# Colour            gray
# Odometer (KM)    41958
# Doors                5
# Price            67301
# Seats              5.0
# Name: 3, dtype: object

# %%
car_sales
# Out:
#         Make   Colour  Odometer (KM)  Doors  Price  Seats
# 0      mazda  fuchsia          79473      4  50116    5.0
# 1     toyota     gray          51047      7  40832    5.0
# 2   infiniti     blue          41587      7  58986    5.0
# 3       ford     gray          41958      5  67301    5.0
# 4        gmc   yellow          75973      6  59806    5.0
# ..       ...      ...            ...    ...    ...    ...
# 95       gmc     gray          66301      4  96958    5.0
# 96  chrysler  fuchsia          15145      5  77949    5.0
# 97  cadillac     teal          54776      6  15387    5.0
# 98     lexus     aqua          72956      4  88575    5.0
# 99     lotus     aqua          93944      2  99848    5.0
#
# [100 rows x 6 columns]

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
car_sales.loc[:3]
# Out:
#        Make   Colour  Odometer (KM)  Doors  Price  Seats
# 0     mazda  fuchsia          79473      4  50116    5.0
# 1    toyota     gray          51047      7  40832    5.0
# 2  infiniti     blue          41587      7  58986    5.0
# 3      ford     gray          41958      5  67301    5.0

# %%
car_sales.head(4)
# Out:
#        Make   Colour  Odometer (KM)  Doors  Price  Seats
# 0     mazda  fuchsia          79473      4  50116    5.0
# 1    toyota     gray          51047      7  40832    5.0
# 2  infiniti     blue          41587      7  58986    5.0
# 3      ford     gray          41958      5  67301    5.0

# %%
car_sales["Make"]
# Out:
# 0        mazda
# 1       toyota
# 2     infiniti
# 3         ford
# 4          gmc
#         ...
# 95         gmc
# 96    chrysler
# 97    cadillac
# 98       lexus
# 99       lotus
# Name: Make, Length: 100, dtype: object

# %%
car_sales["Colour"]
# Out:
# 0     fuchsia
# 1        gray
# 2        blue
# 3        gray
# 4      yellow
#        ...
# 95       gray
# 96    fuchsia
# 97       teal
# 98       aqua
# 99       aqua
# Name: Colour, Length: 100, dtype: object

# %%
car_sales["Make"]
# Out:
# 0        mazda
# 1       toyota
# 2     infiniti
# 3         ford
# 4          gmc
#         ...
# 95         gmc
# 96    chrysler
# 97    cadillac
# 98       lexus
# 99       lotus
# Name: Make, Length: 100, dtype: object

# %%
car_sales["Odometer (KM)"]
# Out:
# 0     79473
# 1     51047
# 2     41587
# 3     41958
# 4     75973
#       ...
# 95    66301
# 96    15145
# 97    54776
# 98    72956
# 99    93944
# Name: Odometer (KM), Length: 100, dtype: int64

# %%
# car_sales.Odometer (KM)   # error#

# %%
car_sales[car_sales["Make"] == "Toyota"]
# Out:
# Empty DataFrame
# Columns: [Make, Colour, Odometer (KM), Doors, Price, Seats]
# Index: []

# %%
car_sales[car_sales["Odometer (KM)"] > 90000]
# Out:
#             Make  Colour  Odometer (KM)  Doors  Price  Seats
# 20          jeep   olive          96627      4  33531    5.0
# 42         dodge   black          99613      7  88029    5.0
# 43         volvo    navy          92501      5  43853    5.0
# 45         lexus    teal          96071      5  73731    5.0
# 50  aston martin  purple          94676      7  58243    5.0
# 62       hyundai    teal          95393      4  76288    5.0
# 67     chevrolet   white          99406      2  72936    5.0
# 69      cadillac   green          98256      4  72217    5.0
# 99         lotus    aqua          93944      2  99848    5.0

# %%
car_sales
# Out:
#         Make   Colour  Odometer (KM)  Doors  Price  Seats
# 0      mazda  fuchsia          79473      4  50116    5.0
# 1     toyota     gray          51047      7  40832    5.0
# 2   infiniti     blue          41587      7  58986    5.0
# 3       ford     gray          41958      5  67301    5.0
# 4        gmc   yellow          75973      6  59806    5.0
# ..       ...      ...            ...    ...    ...    ...
# 95       gmc     gray          66301      4  96958    5.0
# 96  chrysler  fuchsia          15145      5  77949    5.0
# 97  cadillac     teal          54776      6  15387    5.0
# 98     lexus     aqua          72956      4  88575    5.0
# 99     lotus     aqua          93944      2  99848    5.0
#
# [100 rows x 6 columns]

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors          2  3  4  5  6  7
# Make
# acura          0  0  1  0  0  0
# aston martin   0  0  0  0  0  1
# audi           0  1  1  0  0  0
# bentley        0  1  0  0  0  0
# bmw            1  1  2  1  0  0
# buick          0  0  2  0  1  0
# cadillac       1  1  1  0  1  1
# chevrolet      3  3  0  1  2  1
# chrysler       0  0  0  2  0  0
# daewoo         1  0  0  0  0  0
# dodge          1  0  1  2  0  1
# ferrari        0  0  0  0  0  1
# fiat           1  0  0  0  0  0
# ford           2  2  1  3  1  0
# genesis        0  1  0  0  0  0
# gmc            1  0  3  0  1  1
# honda          0  1  0  0  0  0
# hyundai        1  0  1  0  0  0
# infiniti       0  0  0  0  0  1
# isuzu          0  0  0  0  1  0
# jaguar         2  1  0  0  0  0
# jeep           0  0  1  0  1  1
# kia            0  0  0  0  0  1
# land rover     0  0  0  0  1  1
# lexus          0  0  1  1  1  0
# lincoln        0  0  0  0  0  1
# lotus          1  0  0  0  0  0
# mazda          0  0  1  0  0  1
# ...

# %%
# Groupby
# car_sales.groupby(["Make"]).mean()  # error
car_sales.groupby(["Make"]).mean(numeric_only=True)
# Out:
#                Odometer (KM)     Doors         Price  Seats
# Make
# acura           73852.000000  4.000000  98119.000000    5.0
# aston martin    94676.000000  7.000000  58243.000000    5.0
# audi            85106.500000  3.500000  41625.500000    5.0
# bentley          5043.000000  3.000000  60955.000000    5.0
# bmw             43574.600000  3.600000  39823.000000    5.0
# buick           59795.000000  4.666667  71704.000000    5.0
# cadillac        63866.200000  4.400000  56695.800000    5.0
# chevrolet       63291.000000  3.900000  53075.800000    5.0
# chrysler        23398.500000  5.000000  88170.000000    5.0
# daewoo          72828.000000  2.000000  10037.000000    5.0
# dodge           44672.400000  4.600000  84321.200000    5.0
# ferrari         86989.000000  7.000000  97479.000000    5.0
# fiat            13688.000000  2.000000   1858.000000    5.0
# ford            34738.888889  3.888889  73611.333333    5.0
# genesis         15376.000000  3.000000  50440.000000    5.0
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
car_sales["Price"].dtype
# Out:
# dtype('int64')

# %%
# car_sales["Price"].plot() # error

# %%
car_sales
# Out:
#         Make   Colour  Odometer (KM)  Doors  Price  Seats
# 0      mazda  fuchsia          79473      4  50116    5.0
# 1     toyota     gray          51047      7  40832    5.0
# 2   infiniti     blue          41587      7  58986    5.0
# 3       ford     gray          41958      5  67301    5.0
# 4        gmc   yellow          75973      6  59806    5.0
# ..       ...      ...            ...    ...    ...    ...
# 95       gmc     gray          66301      4  96958    5.0
# 96  chrysler  fuchsia          15145      5  77949    5.0
# 97  cadillac     teal          54776      6  15387    5.0
# 98     lexus     aqua          72956      4  88575    5.0
# 99     lotus     aqua          93944      2  99848    5.0
#
# [100 rows x 6 columns]

# %%
# dataframe['amount'] = dataframe['amount'].str.replace('[\$\,\.]', '').astype(int) # sample

# %%
car_sales["Price"]
# Out:
# 0     50116
# 1     40832
# 2     58986
# 3     67301
# 4     59806
#       ...
# 95    96958
# 96    77949
# 97    15387
# 98    88575
# 99    99848
# Name: Price, Length: 100, dtype: int64

# %%
# # car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '') #.astype(int)
# car_sales["Price"] = car_sales["Price"].str.replace('[^0-9]', '', regex=True).astype('int64')
# car_sales["Price"]

# %%
car_sales["Price"].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Manipulating Data

# %%
car_sales["Make"].str.lower()
# Out:
# 0        mazda
# 1       toyota
# 2     infiniti
# 3         ford
# 4          gmc
#         ...
# 95         gmc
# 96    chrysler
# 97    cadillac
# 98       lexus
# 99       lotus
# Name: Make, Length: 100, dtype: object

# %%
car_sales
# Out:
#         Make   Colour  Odometer (KM)  Doors  Price  Seats
# 0      mazda  fuchsia          79473      4  50116    5.0
# 1     toyota     gray          51047      7  40832    5.0
# 2   infiniti     blue          41587      7  58986    5.0
# 3       ford     gray          41958      5  67301    5.0
# 4        gmc   yellow          75973      6  59806    5.0
# ..       ...      ...            ...    ...    ...    ...
# 95       gmc     gray          66301      4  96958    5.0
# 96  chrysler  fuchsia          15145      5  77949    5.0
# 97  cadillac     teal          54776      6  15387    5.0
# 98     lexus     aqua          72956      4  88575    5.0
# 99     lotus     aqua          93944      2  99848    5.0
#
# [100 rows x 6 columns]

# %%
car_sales["Make"] = car_sales["Make"].str.lower()
# Out:
# /tmp/ipykernel_13944/86894582.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#         Make   Colour  Odometer (KM)  Doors  Price  Seats
# 0      mazda  fuchsia          79473      4  50116    5.0
# 1     toyota     gray          51047      7  40832    5.0
# 2   infiniti     blue          41587      7  58986    5.0
# 3       ford     gray          41958      5  67301    5.0
# 4        gmc   yellow          75973      6  59806    5.0
# ..       ...      ...            ...    ...    ...    ...
# 95       gmc     gray          66301      4  96958    5.0
# 96  chrysler  fuchsia          15145      5  77949    5.0
# 97  cadillac     teal          54776      6  15387    5.0
# 98     lexus     aqua          72956      4  88575    5.0
# 99     lotus     aqua          93944      2  99848    5.0
#
# [100 rows x 6 columns]

# %%
car_sales
# Out:
#         Make   Colour  Odometer (KM)  Doors  Price  Seats
# 0      mazda  fuchsia          79473      4  50116    5.0
# 1     toyota     gray          51047      7  40832    5.0
# 2   infiniti     blue          41587      7  58986    5.0
# 3       ford     gray          41958      5  67301    5.0
# 4        gmc   yellow          75973      6  59806    5.0
# ..       ...      ...            ...    ...    ...    ...
# 95       gmc     gray          66301      4  96958    5.0
# 96  chrysler  fuchsia          15145      5  77949    5.0
# 97  cadillac     teal          54776      6  15387    5.0
# 98     lexus     aqua          72956      4  88575    5.0
# 99     lotus     aqua          93944      2  99848    5.0
#
# [100 rows x 6 columns]

# %%
car_sales_missing = pd.read_csv("../data/car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].mean()
# Out:
# 92302.66666666667

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(),
                                     inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing = pd.read_csv("../data/car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped.to_csv("car-sales-missing-dropped.csv")

# %%
car_sales
# Out:
#         Make   Colour  Odometer (KM)  Doors  Price  Seats
# 0      mazda  fuchsia          79473      4  50116    5.0
# 1     toyota     gray          51047      7  40832    5.0
# 2   infiniti     blue          41587      7  58986    5.0
# 3       ford     gray          41958      5  67301    5.0
# 4        gmc   yellow          75973      6  59806    5.0
# ..       ...      ...            ...    ...    ...    ...
# 95       gmc     gray          66301      4  96958    5.0
# 96  chrysler  fuchsia          15145      5  77949    5.0
# 97  cadillac     teal          54776      6  15387    5.0
# 98     lexus     aqua          72956      4  88575    5.0
# 99     lotus     aqua          93944      2  99848    5.0
#
# [100 rows x 6 columns]

# %%
# Column from series
seats_column = pd.Series([5, 5, 5, 5, 5])

# New column called seats
car_sales["Seats"] = seats_column
car_sales
# Out:
# /tmp/ipykernel_13944/401719009.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_sales["Seats"] = seats_column
#         Make   Colour  Odometer (KM)  Doors  Price  Seats
# 0      mazda  fuchsia          79473      4  50116    5.0
# 1     toyota     gray          51047      7  40832    5.0
# 2   infiniti     blue          41587      7  58986    5.0
# 3       ford     gray          41958      5  67301    5.0
# 4        gmc   yellow          75973      6  59806    5.0
# ..       ...      ...            ...    ...    ...    ...
# 95       gmc     gray          66301      4  96958    NaN
# 96  chrysler  fuchsia          15145      5  77949    NaN
# 97  cadillac     teal          54776      6  15387    NaN
# ...

# %%
car_sales["Seats"].fillna(5, inplace=True)
# Out:
# /tmp/ipykernel_13944/1647811259.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_sales["Seats"].fillna(5, inplace=True)

# %%
car_sales
# Out:
#         Make   Colour  Odometer (KM)  Doors  Price  Seats
# 0      mazda  fuchsia          79473      4  50116    5.0
# 1     toyota     gray          51047      7  40832    5.0
# 2   infiniti     blue          41587      7  58986    5.0
# 3       ford     gray          41958      5  67301    5.0
# 4        gmc   yellow          75973      6  59806    5.0
# ..       ...      ...            ...    ...    ...    ...
# 95       gmc     gray          66301      4  96958    5.0
# 96  chrysler  fuchsia          15145      5  77949    5.0
# 97  cadillac     teal          54776      6  15387    5.0
# 98     lexus     aqua          72956      4  88575    5.0
# 99     lotus     aqua          93944      2  99848    5.0
#
# [100 rows x 6 columns]

# %%
# Column from Python list
fuel_economy = [7.5, 9.2, 5.0, 9.6, 8.7, 4.7, 7.6, 8.7, 3.0, 4.5]

# using faker to fake fuel_economy data, try list comprehension, the data length must match with car_sales
import faker
fake = faker.Faker()
fuel_economy = [fake.pyfloat(left_digits=1, right_digits=1, positive=True) for i in range(len(car_sales))]
car_sales["Fuel per 100KM"] = fuel_economy
car_sales
# Out:
# /tmp/ipykernel_13944/3051969527.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_sales["Fuel per 100KM"] = fuel_economy
#         Make   Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM
# 0      mazda  fuchsia          79473      4  50116    5.0             7.4
# 1     toyota     gray          51047      7  40832    5.0             7.3
# 2   infiniti     blue          41587      7  58986    5.0             3.2
# 3       ford     gray          41958      5  67301    5.0             3.9
# 4        gmc   yellow          75973      6  59806    5.0             0.3
# ..       ...      ...            ...    ...    ...    ...             ...
# 95       gmc     gray          66301      4  96958    5.0             9.2
# ...

# %%
car_sales["Total fuel used (L)"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100KM"]
# Out:
# /tmp/ipykernel_13944/1619949246.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_sales["Total fuel used (L)"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100KM"]

# %%
car_sales
# Out:
#         Make   Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0      mazda  fuchsia          79473      4  50116    5.0             7.4
# 1     toyota     gray          51047      7  40832    5.0             7.3
# 2   infiniti     blue          41587      7  58986    5.0             3.2
# 3       ford     gray          41958      5  67301    5.0             3.9
# 4        gmc   yellow          75973      6  59806    5.0             0.3
# ..       ...      ...            ...    ...    ...    ...             ...
# 95       gmc     gray          66301      4  96958    5.0             9.2
# 96  chrysler  fuchsia          15145      5  77949    5.0             8.4
# 97  cadillac     teal          54776      6  15387    5.0             0.7
# 98     lexus     aqua          72956      4  88575    5.0             3.1
# 99     lotus     aqua          93944      2  99848    5.0             2.2
#
#     Total fuel used (L)
# 0              5881.002
# 1              3726.431
# ...

# %%
# Create a column from a single value
car_sales["Number of wheels"] = 4
car_sales
# Out:
# /tmp/ipykernel_13944/319576349.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_sales["Number of wheels"] = 4
#         Make   Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0      mazda  fuchsia          79473      4  50116    5.0             7.4
# 1     toyota     gray          51047      7  40832    5.0             7.3
# 2   infiniti     blue          41587      7  58986    5.0             3.2
# 3       ford     gray          41958      5  67301    5.0             3.9
# 4        gmc   yellow          75973      6  59806    5.0             0.3
# ..       ...      ...            ...    ...    ...    ...             ...
# 95       gmc     gray          66301      4  96958    5.0             9.2
# ...

# %%
car_sales["Passed road saftey"] = True
car_sales.dtypes
# Out:
# /tmp/ipykernel_13944/1305384745.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_sales["Passed road saftey"] = True
# Make                    object
# Colour                  object
# Odometer (KM)            int64
# Doors                    int64
# Price                    int64
# Seats                  float64
# Fuel per 100KM         float64
# Total fuel used (L)    float64
# Number of wheels         int64
# Passed road saftey        bool
# dtype: object

# %%
car_sales
# Out:
#         Make   Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0      mazda  fuchsia          79473      4  50116    5.0             7.4
# 1     toyota     gray          51047      7  40832    5.0             7.3
# 2   infiniti     blue          41587      7  58986    5.0             3.2
# 3       ford     gray          41958      5  67301    5.0             3.9
# 4        gmc   yellow          75973      6  59806    5.0             0.3
# ..       ...      ...            ...    ...    ...    ...             ...
# 95       gmc     gray          66301      4  96958    5.0             9.2
# 96  chrysler  fuchsia          15145      5  77949    5.0             8.4
# 97  cadillac     teal          54776      6  15387    5.0             0.7
# 98     lexus     aqua          72956      4  88575    5.0             3.1
# 99     lotus     aqua          93944      2  99848    5.0             2.2
#
#     Total fuel used (L)  Number of wheels  Passed road saftey
# ...

# %%
# car_sales = car_sales.drop("Total fuel used", axis=1)

# %%
car_sales
# Out:
#         Make   Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0      mazda  fuchsia          79473      4  50116    5.0             7.4
# 1     toyota     gray          51047      7  40832    5.0             7.3
# 2   infiniti     blue          41587      7  58986    5.0             3.2
# 3       ford     gray          41958      5  67301    5.0             3.9
# 4        gmc   yellow          75973      6  59806    5.0             0.3
# ..       ...      ...            ...    ...    ...    ...             ...
# 95       gmc     gray          66301      4  96958    5.0             9.2
# 96  chrysler  fuchsia          15145      5  77949    5.0             8.4
# 97  cadillac     teal          54776      6  15387    5.0             0.7
# 98     lexus     aqua          72956      4  88575    5.0             3.1
# 99     lotus     aqua          93944      2  99848    5.0             2.2
#
#     Total fuel used (L)  Number of wheels  Passed road saftey
# ...

# %%
car_sales_shuffled = car_sales.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#             Make   Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 9           fiat     aqua          13688      2   1858    5.0             7.7
# 82       hyundai     lime          68434      2  59222    5.0             5.8
# 50  aston martin   purple          94676      7  58243    5.0             0.6
# 66      plymouth    black          65655      4  81386    5.0             7.1
# 12        daewoo    olive          72828      2  10037    5.0             9.0
# ..           ...      ...            ...    ...    ...    ...             ...
# 57          jeep     lime          21130      7  27624    5.0             8.7
# 81           bmw     lime          31970      3  50841    5.0             5.8
# 96      chrysler  fuchsia          15145      5  77949    5.0             8.4
# 11     chevrolet    white          82172      6  89900    5.0             3.5
# 13          mini   maroon          66904      3  57786    5.0             7.3
#
# ...

# %%
# Only select 20% of data
car_sales_shuffled.sample(frac=0.01)
# Out:
#        Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 59  hyundai   teal          95393      4  76288    5.0             3.6
#
#     Total fuel used (L)  Number of wheels  Passed road saftey
# 59             3434.148                 4                True

# %%
car_sales_shuffled
# Out:
#             Make   Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0           fiat     aqua          13688      2   1858    5.0             7.7
# 1        hyundai     lime          68434      2  59222    5.0             5.8
# 2   aston martin   purple          94676      7  58243    5.0             0.6
# 3       plymouth    black          65655      4  81386    5.0             7.1
# 4         daewoo    olive          72828      2  10037    5.0             9.0
# ..           ...      ...            ...    ...    ...    ...             ...
# 95          jeep     lime          21130      7  27624    5.0             8.7
# 96           bmw     lime          31970      3  50841    5.0             5.8
# 97      chrysler  fuchsia          15145      5  77949    5.0             8.4
# 98     chevrolet    white          82172      6  89900    5.0             3.5
# 99          mini   maroon          66904      3  57786    5.0             7.3
#
# ...

# %%
car_sales_shuffled.reset_index(drop=True, inplace=True)

# %%
car_sales_shuffled
# Out:
#             Make   Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0           fiat     aqua          13688      2   1858    5.0             7.7
# 1        hyundai     lime          68434      2  59222    5.0             5.8
# 2   aston martin   purple          94676      7  58243    5.0             0.6
# 3       plymouth    black          65655      4  81386    5.0             7.1
# 4         daewoo    olive          72828      2  10037    5.0             9.0
# ..           ...      ...            ...    ...    ...    ...             ...
# 95          jeep     lime          21130      7  27624    5.0             8.7
# 96           bmw     lime          31970      3  50841    5.0             5.8
# 97      chrysler  fuchsia          15145      5  77949    5.0             8.4
# 98     chevrolet    white          82172      6  89900    5.0             3.5
# 99          mini   maroon          66904      3  57786    5.0             7.3
#
# ...

# %%
car_sales
# Out:
#         Make   Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0      mazda  fuchsia      49670.625      4  50116    5.0             7.4
# 1     toyota     gray      31904.375      7  40832    5.0             7.3
# 2   infiniti     blue      25991.875      7  58986    5.0             3.2
# 3       ford     gray      26223.750      5  67301    5.0             3.9
# 4        gmc   yellow      47483.125      6  59806    5.0             0.3
# ..       ...      ...            ...    ...    ...    ...             ...
# 95       gmc     gray      41438.125      4  96958    5.0             9.2
# 96  chrysler  fuchsia       9465.625      5  77949    5.0             8.4
# 97  cadillac     teal      34235.000      6  15387    5.0             0.7
# 98     lexus     aqua      45597.500      4  88575    5.0             3.1
# 99     lotus     aqua      58715.000      2  99848    5.0             2.2
#
#     Total fuel used (L)  Number of wheels  Passed road saftey
# ...

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x: x / 1.6)
car_sales
# Out:
# /tmp/ipykernel_13944/1487290866.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x: x / 1.6)
#         Make   Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0      mazda  fuchsia   31044.140625      4  50116    5.0             7.4
# 1     toyota     gray   19940.234375      7  40832    5.0             7.3
# 2   infiniti     blue   16244.921875      7  58986    5.0             3.2
# 3       ford     gray   16389.843750      5  67301    5.0             3.9
# 4        gmc   yellow   29676.953125      6  59806    5.0             0.3
# ..       ...      ...            ...    ...    ...    ...             ...
# ...

# %%
# Try it, run your code
# Search for it
# Try again
# Ask
